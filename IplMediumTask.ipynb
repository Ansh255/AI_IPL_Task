# %%
import pandas as pd

# %%
dataframe_for_medium= pd.read_excel("EASY_IPL.xlsx")

# %%
dataframe_for_medium
# Out:
#      Match_Number         Match    Date  Year      Venue Team_Batting_First  \
# 0               1  League Match  Apr 18  2008  Bangalore            Kolkata
# 1               2  League Match  Apr 19  2008     Mohali            Chennai
# 2               3  League Match  Apr 19  2008      Delhi          Rajasthan
# 3               4  League Match  Apr 20  2008    Kolkata          Hyderabad
# 4               5  League Match  Apr 20  2008     Mumbai             Mumbai
# ..            ...           ...     ...   ...        ...                ...
# 509           510  League Match  May 17  2015  Hyderabad          Hyderabad
# 510           511   Qualifier 1  May 19  2015     Mumbai             Mumbai
# 511           512    Eliminator  May 20  2015       Pune          Bangalore
# 512           513   Qualifier 2  May 22  2015     Ranchi          Bangalore
# 513           514         Final  May 24  2015    Kolkata             Mumbai
#
# ...

# %%
#Checking Number of rows and Columns
dataframe_for_medium.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 514 entries, 0 to 513
# Data columns (total 43 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Match_Number                514 non-null    int64
#  1   Match                       514 non-null    object
#  2   Date                        514 non-null    object
#  3   Year                        514 non-null    int64
#  4   Venue                       514 non-null    object
#  5   Team_Batting_First          514 non-null    object
#  6   Team_Batting_Second         514 non-null    object
#  7   Bat_First_Runs_Scored       514 non-null    int64
#  8   Bat_First_Wickets_Lost      514 non-null    int64
#  9   Bat_First_Overs_Consumed    514 non-null    float64
#  10  Bat_First_Overs_Allocated   514 non-null    int64
#  11  Bat_Second_Runs_Scored      514 non-null    int64
#  12  Bat_Second_Wickets_Lost     514 non-null    int64
# ...

# %%
condition_check = (dataframe_for_medium['Winning_Team']=='Match Tied') |  ((dataframe_for_medium['Balls_Remaining']<=3)) | ((dataframe_for_medium['Winning_Team'] =='Chasing') & (dataframe_for_medium['Winning_Margin'] <=1 ) & (dataframe_for_medium['Win_Type'] == 'wicket')) | ((dataframe_for_medium['Winning_Team'] == 'FirstBatting') & (dataframe_for_medium['Winning_Margin'] <=5) & (dataframe_for_medium['Win_Type'] == 'run'))

# %%
condition_check_for_close_match = dataframe_for_medium[condition_check]

# %%
condition_check_for_close_match
# Out:
#      Match_Number         Match    Date  Year        Venue Team_Batting_First  \
# 1               2  League Match  Apr 19  2008       Mohali            Chennai
# 4               5  League Match  Apr 20  2008       Mumbai             Mumbai
# 7               8  League Match  Apr 23  2008      Chennai            Chennai
# 8               9  League Match  Apr 24  2008    Hyderabad          Hyderabad
# 9              10  League Match  Apr 25  2008       Mohali             Punjab
# ..            ...           ...     ...   ...          ...                ...
# 505           506  League Match  May 14  2015       Mumbai             Mumbai
# 506           507  League Match  May 15  2015    Hyderabad          Hyderabad
# 508           509  League Match  May 16  2015  Mumbai (BS)          Rajasthan
# 512           513   Qualifier 2  May 22  2015       Ranchi          Bangalore
# 513           514         Final  May 24  2015      Kolkata             Mumbai
#
# ...

# %%
close_matches_per_year = condition_check_for_close_match.groupby('Year').size()

# %%
close_matches_per_year
# Out:
# Year
# 2008    28
# 2009    33
# 2010    28
# 2011    35
# 2012    46
# 2013    39
# 2014    33
# 2015    39
# dtype: int64

# %%
#Task 2 Starts

# %%
chennai_win = (dataframe_for_medium['Winner']=='Chennai').sum()
chennai_win
# Out:
# 79

# %%
chennai_win_with_firstbat = (dataframe_for_medium['Winner']=='Chennai') & (dataframe_for_medium['Winning_Team']=='FirstBatting')
chennai_win_with_firstbat.sum()
# Out:
# 45

# %%
Chennai= (chennai_win_with_firstbat/chennai_win*100).sum()
Chennai
# Out:
# 56.962025316455694

# %%
hybd_win = (dataframe_for_medium['Winner']=='Hyderabad').sum()
hybd_win
# Out:
# 51

# %%
hybd_win_with_firstbat = (dataframe_for_medium['Winner']=='Hyderabad') & (dataframe_for_medium['Winning_Team']=='FirstBatting')
hybd_win_with_firstbat.sum()
# Out:
# 31

# %%
Hyderabad = (hybd_win_with_firstbat/hybd_win*100).sum()
Hyderabad
# Out:
# 60.78431372549019

# %%
mumbai_win = (dataframe_for_medium['Winner']=='Mumbai').sum()
mumbai_win
# Out:
# 73

# %%
mumbai_win_with_firstbat = (dataframe_for_medium['Winner']=='Mumbai') & (dataframe_for_medium['Winning_Team']=='FirstBatting')
mumbai_win_with_firstbat.sum()
# Out:
# 41

# %%
Mumbai= (mumbai_win_with_firstbat/mumbai_win*100).sum()
Mumbai
# Out:
# 56.16438356164383

# %%
kolkata_win = (dataframe_for_medium['Winner']=='Kolkata').sum()
kolkata_win
# Out:
# 60

# %%
kolkata_win_with_firstbat = (dataframe_for_medium['Winner']=='Kolkata') & (dataframe_for_medium['Winning_Team']=='FirstBatting')
kolkata_win_with_firstbat.sum()
# Out:
# 25

# %%
Kolkata= (kolkata_win_with_firstbat/kolkata_win*100).sum()
Kolkata
# Out:
# 41.66666666666667

# %%
data = {
    'Team': ['Chennai', 'Hyderabad', 'Mumbai', 'Kolkata'],
    'Percent won batting first': [Chennai, Hyderabad, Mumbai, Kolkata]
}

df = pd.DataFrame(data)
df
# Out:
#         Team  Percent won batting first
# 0    Chennai                  56.962025
# 1  Hyderabad                  60.784314
# 2     Mumbai                  56.164384
# 3    Kolkata                  41.666667
